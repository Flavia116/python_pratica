# %%
# Etapa 6 - Salvar modelo
# Projeto: Classificação de imagens com PyTorch (DSA)

# %%
torch.save(modelo_dsa.state_dict(), 'modelo_dsa.pth')

model_carregado = Convnet().to(device)
model_carregado.load_state_dict(torch.load('modelo_dsa.pth'))

model_carregado.eval()
