# %%
# Etapa 3 - Visualização
# Projeto: Classificação de imagens com PyTorch (DSA)

# %%
import matplotlib.pyplot as plt
import numpy as np
import torchvision

def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(dsa_loarders_treino) ##definiçao dsa_loarders_treino está definida no bloco "02_dados"
imagens, labels = next(dataiter)

imshow(torchvision.utils.make_grid(imagens[:4]))

print(' '.join(f'{classes[labels[j]]}' for j in range(4)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5270/2041478739.py in <cell line: 0>()
#       9     plt.show()
#      10
# ---> 11 dataiter = iter(dsa_loarders_treino)
#      12 imagens, labels = next(dataiter)
#      13
#
# NameError: name 'dsa_loarders_treino' is not defined
